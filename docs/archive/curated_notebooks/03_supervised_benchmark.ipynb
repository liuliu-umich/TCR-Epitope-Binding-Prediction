# %% [markdown]
# # 03 Supervised Benchmark
#
# This notebook is the polished benchmark-facing entry for the case study. The full historical benchmark notebook is archived in [`docs/archive/legacy_notebooks`](/Users/newuser/TCR_Binding_Prediction/docs/archive/legacy_notebooks), while this version keeps the headline comparisons and the reader-facing story.

# %% [markdown]
# ## Models Compared
#
# | Model | Feature setting | ROC-AUC | F1 | Accuracy |
# | --- | --- | ---: | ---: | ---: |
# | Logistic Regression | all features | 0.9136 | 0.8442 | 0.8328 |
# | Random Forest | all features | 0.9147 | 0.8510 | 0.8389 |
# | XGBoost | all features | 0.9145 | 0.8497 | 0.8351 |
# | Logistic Regression | top 200 | 0.9061 | 0.8410 | 0.8261 |
# | Random Forest | top 200 | 0.9184 | 0.8482 | 0.8391 |
# | XGBoost | top 200 | **0.9198** | **0.8541** | **0.8399** |

# %% [markdown]
# ## Result Figures
#
# ![ROC and PR curves](docs/figures/roc_pr_curves.png)
#
# ![Confusion matrix](docs/figures/confusion_matrix.svg)

# %%
headline_result = {
    'model': 'XGBoost (top 200)',
    'roc_auc': 0.9198,
    'f1': 0.8541,
    'accuracy': 0.8399,
    'precision': 0.7844,
    'recall': 0.9374,
}
headline_result

# %% [markdown]
# ## Interpretation
#
# - This repository is a benchmark / case study for sequence ML, not a production binding predictor.
# - The strongest downstream result came from the top-200 XGBoost benchmark in the final notebook lineage.
# - The benchmark is useful as a portfolio proof of end-to-end ML execution: data curation, representation work, unsupervised exploration, supervised comparison, and result communication.
