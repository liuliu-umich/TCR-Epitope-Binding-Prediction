# %% [markdown]
# # 02 Representation And Exploration
#
# This notebook is the presentation-layer summary of the representation engineering and unsupervised exploration stage. The detailed experimental notebook that produced the original plots is archived in [`docs/archive/legacy_notebooks`](/Users/newuser/TCR_Binding_Prediction/docs/archive/legacy_notebooks).

# %% [markdown]
# ## Representations Compared
#
# - amino acid composition descriptors
# - dipeptide composition
# - CTD physicochemical descriptors
# - one-hot sequence encodings
# - ESM protein language model embeddings
# - PCA / UMAP / KMeans-derived unsupervised features

# %% [markdown]
# ## Embedding Snapshot
#
# The figure below is extracted from the original unsupervised exploration notebook and highlights how the representation stage was used for structure discovery before supervised benchmarking.
#
# ![Embedding visualization](docs/figures/embedding_visualization.png)

# %%
representation_methods = [
    'AAC',
    'DPC',
    'CTD',
    'one-hot',
    'ESM embeddings',
    'PCA / UMAP / KMeans features',
]
representation_methods

# %% [markdown]
# ## Why This Stage Matters
#
# The goal here was not to claim novel biology from clustering alone. Instead, this stage demonstrates sequence representation engineering, dimensionality reduction, and feature discovery as part of a complete ML workflow.
